# %%
fh=open('mbox-short.txt')
for line in fh:
    line=line.rstrip()
    #if line.search("From:",line): -- line contains From
    #if line.search("^From:",line): -- line starts with From
    if re.search("^From.*@",line):  #lin
        print(line)
fh.close()
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# From: stephen.marquard@uct.ac.za
# From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008
# From: louis@media.berkeley.edu
# From zqian@umich.edu Fri Jan  4 16:10:39 2008
# From: zqian@umich.edu
# From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008
# From: rjlowe@iupui.edu
# From zqian@umich.edu Fri Jan  4 15:03:18 2008
# From: zqian@umich.edu
# From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008
# From: rjlowe@iupui.edu
# From cwen@iupui.edu Fri Jan  4 11:37:30 2008
# From: cwen@iupui.edu
# From cwen@iupui.edu Fri Jan  4 11:35:08 2008
# From: cwen@iupui.edu
# From gsilver@umich.edu Fri Jan  4 11:12:37 2008
# From: gsilver@umich.edu
# From gsilver@umich.edu Fri Jan  4 11:11:52 2008
# From: gsilver@umich.edu
# From zqian@umich.edu Fri Jan  4 11:11:03 2008
# From: zqian@umich.edu
# From gsilver@umich.edu Fri Jan  4 11:10:22 2008
# From: gsilver@umich.edu
# From wagnermr@iupui.edu Fri Jan  4 10:38:42 2008
# From: wagnermr@iupui.edu
# ...

# %%
import math
class Point:
    """ 
    Point class
      x,y
    """
  
def print_point(p):
    print('(%g,%g)'%(p.x,p.y))
def distance(p1,p2):
    d=math.sqrt((p2.x-p1.x)**2 + (p2.y-p1.y)**2)
    print('(%g,)'%(d,))
p=Point()
p.x=-4
p.y=-1
o=Point()
o.x=1
o.y=2
print_point(p)
distance(o,p)
# Out:
# (-4,-1)
# (5.83095,)

# %%
p

# %%
p.x
# Out:
# 2

# %%
import re
fh=open('mbox-short.txt')
for line in fh:
    line=line.rstrip()
    lst=re.findall("[a-zA-Z0-9]+@\S[a-zA-Z]+",line)
    if len(lst)>0:
        print(lst)
fh.close()
# Out:
# ['marquard@uct']
# ['postmaster@collab']
# ['m05ECIaH010327@nakamura']
# ['source@collab']
# ['source@collab']
# ['source@collab']
# ['apache@localhost']
# ['source@collab']
# ['marquard@uct']
# ['source@collab']
# ['marquard@uct']
# ['marquard@uct']
# ['louis@media']
# ['postmaster@collab']
# ['m04N8v6O008125@nakamura']
# ['source@collab']
# ['source@collab']
# ['source@collab']
# ['apache@localhost']
# ['source@collab']
# ['louis@media']
# ['source@collab']
# ['louis@media']
# ['louis@media']
# ['zqian@umich']
# ['postmaster@collab']
# ['m04L92hb007923@nakamura']
# ['source@collab']
# ['source@collab']
# ['source@collab']
# ['apache@localhost']
# ['source@collab']
# ['zqian@umich']
# ['source@collab']
# ['zqian@umich']
# ['zqian@umich']
# ['rjlowe@iupui']
# ['postmaster@collab']
# ['m04Kiem3007881@nakamura']
# ['source@collab']
# ['source@collab']
# ['source@collab']
# ['apache@localhost']
# ['source@collab']
# ['rjlowe@iupui']
# ['source@collab']
# ['rjlowe@iupui']
# ...

# %%
import re
fh=open('mbox-short.txt')
for line in fh:
    line=line.rstrip()
    lst=re.findall("^X-.*: ([0-9.]+)",line)
    if len(lst)>0:
        print(lst)
fh.close()
# Out:
# ['0.8475']
# ['0.0000']
# ['0.6178']
# ['0.0000']
# ['0.6961']
# ['0.0000']
# ['0.7565']
# ['0.0000']
# ['0.7626']
# ['0.0000']
# ['0.7556']
# ['0.0000']
# ['0.7002']
# ['0.0000']
# ['0.7615']
# ['0.0000']
# ['0.7601']
# ['0.0000']
# ['0.7605']
# ['0.0000']
# ['0.6959']
# ['0.0000']
# ['0.7606']
# ['0.0000']
# ['0.7559']
# ['0.0000']
# ['0.7605']
# ['0.0000']
# ['0.6932']
# ['0.0000']
# ['0.7558']
# ['0.0000']
# ['0.6526']
# ['0.0000']
# ['0.6948']
# ['0.0000']
# ['0.6528']
# ['0.0000']
# ['0.7002']
# ['0.0000']
# ['0.7554']
# ['0.0000']
# ['0.6956']
# ['0.0000']
# ['0.6959']
# ['0.0000']
# ['0.7556']
# ['0.0000']
# ['0.9846']
# ['0.0000']
# ['0.8509']
# ['0.0000']
# ['0.9907']
# ['0.0000']

# %%
import re
fh=open('mbox-short.txt')
for line in fh:
    line=line.rstrip()
    lst=re.findall("^Details:.*(rev=[0-9]+)",line)
    if len(lst)>0:
        print(lst)
fh.close()
# Out:
# ['rev=39772']
# ['rev=39771']
# ['rev=39770']
# ['rev=39769']
# ['rev=39766']
# ['rev=39765']
# ['rev=39764']
# ['rev=39763']
# ['rev=39762']
# ['rev=39761']
# ['rev=39760']
# ['rev=39759']
# ['rev=39758']
# ['rev=39757']
# ['rev=39756']
# ['rev=39755']
# ['rev=39754']
# ['rev=39753']
# ['rev=39752']
# ['rev=39751']
# ['rev=39750']
# ['rev=39749']
# ['rev=39746']
# ['rev=39745']
# ['rev=39744']
# ['rev=39743']
# ['rev=39742']

# %%
import re
fh=open('mbox-short.txt')
for line in fh:
    line=line.rstrip()
    lst=re.findall("^From.*([0-9][0-9]):",line)
    if len(lst)>0:
        print(lst)
fh.close()
# Out:
# ['14']
# ['10']
# ['10']
# ['46']
# ['03']
# ['50']
# ['37']
# ['35']
# ['12']
# ['11']
# ['11']
# ['10']
# ['38']
# ['17']
# ['04']
# ['05']
# ['02']
# ['08']
# ['49']
# ['33']
# ['07']
# ['51']
# ['18']
# ['07']
# ['34']
# ['29']
# ['23']

# %%
s="This apple costs 40$ and pineapple 20$"
lst=re.findall("([0-9]+\$)",s)
lst
# Out:
# ['40$', '20$']
